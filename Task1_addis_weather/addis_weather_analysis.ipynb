# %% [markdown]
# <a href="https://colab.research.google.com/github/unahel9-beep/Human_right_incentives_fundraising-_data/blob/main/Task1_addis_weather/addis_weather_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

avg_high = data["High (°C)"].mean()
avg_low = data["Low (°C)"].mean()
print("Average High:", round(avg_high,1), "°C")
print("Average Low:", round(avg_low,1), "°C")

plt.plot(data["Date"], data["High (°C)"], marker='o', color='orange', label='High')
plt.plot(data["Date"], data["Low (°C)"], marker='o', color='blue', label='Low')
plt.title("Addis Ababa Temperatures (Oct 14–21, 2025)")
plt.xlabel("Date"); plt.ylabel("°C"); plt.legend(); plt.grid(True)
plt.show()
# Out:
# Average High: 22.1 °C
# Average Low: 12.6 °C
